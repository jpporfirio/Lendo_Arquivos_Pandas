# %% [markdown]
# <a href="https://colab.research.google.com/github/jpporfirio/Lendo_Arquivos_Pandas/blob/main/lendo_arquivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lendo e carregando dados .csv

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas/main/superstore_data.csv'
dados_mercado = pd.read_csv(url)

# %%
dados_mercado.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
dados_mercado.info()

# %%
dados_mercado.shape
# Out:
# (2240, 22)

# %%
url_2 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/superstore_data_ponto_virgula.csv'
pd.read_csv(url_2, sep = ';')

# %%
dados_primeiras_linhas = pd.read_csv(url, nrows= 5)
dados_primeiras_linhas

# %%
dados_selecao = pd.read_csv(url, usecols= [1, 4])
dados_selecao
# Out:
#       Year_Birth   Income
# 0           1970  84835.0
# 1           1961  57091.0
# 2           1958  67267.0
# 3           1967  32474.0
# 4           1989  21474.0
# ...          ...      ...
# 2235        1976  66476.0
# 2236        1977  31056.0
# 2237        1976  46310.0
# 2238        1978  65819.0
# 2239        1969  94871.0
#
# [2240 rows x 2 columns]

# %%
dados_selecao.to_csv('dados_selecionados.csv', index = False, sep = ',')

# %%
pd.read_csv('dados_selecionados.csv')
# Out:
#       Year_Birth   Income
# 0           1970  84835.0
# 1           1961  57091.0
# 2           1958  67267.0
# 3           1967  32474.0
# 4           1989  21474.0
# ...          ...      ...
# 2235        1976  66476.0
# 2236        1977  31056.0
# 2237        1976  46310.0
# 2238        1978  65819.0
# 2239        1969  94871.0
#
# [2240 rows x 2 columns]

# %%
clientes_mercado = pd.read_csv('/content/dados_selecionados.csv')
clientes_mercado
# Out:
#       Year_Birth   Income
# 0           1970  84835.0
# 1           1961  57091.0
# 2           1958  67267.0
# 3           1967  32474.0
# 4           1989  21474.0
# ...          ...      ...
# 2235        1976  66476.0
# 2236        1977  31056.0
# 2237        1976  46310.0
# 2238        1978  65819.0
# 2239        1969  94871.0
#
# [2240 rows x 2 columns]

# %% [markdown]
# # Lendo e carrengando dados .xlsx

# %%
import pandas as pd

# %%
url = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'

# %%
dados_co2 = pd.read_excel(url)

# %%
dados_co2.head()

# %%
pd.ExcelFile(url).sheet_names

# %%
percapita = pd.read_excel(url, sheet_name='emissoes_percapita')

# %%
percapita.head()

# %%
fontes = pd.read_excel(url, sheet_name='fontes')

# %%
fontes.head()

# %%
intervalo = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D')

# %%
intervalo
# Out:
#               País ISO 3166-1 alpha-3   Ano         Total
# 0      Afeganistão                AFG  1750  0.000000e+00
# 1      Afeganistão                AFG  1751  0.000000e+00
# 2      Afeganistão                AFG  1752  0.000000e+00
# 3      Afeganistão                AFG  1753  0.000000e+00
# 4      Afeganistão                AFG  1754  0.000000e+00
# ...            ...                ...   ...           ...
# 63099       Global                WLD  2017  3.609674e+10
# 63100       Global                WLD  2018  3.682651e+10
# 63101       Global                WLD  2019  3.708256e+10
# 63102       Global                WLD  2020  3.526409e+10
# 63103       Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
intervalo_2 = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D', nrows= 10)

# %%
intervalo_2
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0
# 5  Afeganistão                AFG  1755      0
# 6  Afeganistão                AFG  1756      0
# 7  Afeganistão                AFG  1757      0
# 8  Afeganistão                AFG  1758      0
# 9  Afeganistão                AFG  1759      0

# %%
percapita.to_excel('co2_percapita.xlsx', index = False, )

# %%
pd.read_excel('/content/co2_percapita.xlsx')
# Out:
#               País ISO 3166-1 alpha-3   Ano      Total     Carvão       Óleo  \
# 0      Afeganistão                AFG  1750        NaN        NaN        NaN
# 1      Afeganistão                AFG  1751        NaN        NaN        NaN
# 2      Afeganistão                AFG  1752        NaN        NaN        NaN
# 3      Afeganistão                AFG  1753        NaN        NaN        NaN
# 4      Afeganistão                AFG  1754        NaN        NaN        NaN
# ...            ...                ...   ...        ...        ...        ...
# 63099       Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100       Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101       Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102       Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103       Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gás   Cimento   Queima    Outro
# ...

# %%
# https://docs.google.com/spreadsheets/d/1FYVtRCeZIB-tp1mikSyH1E0vsQb5zMYCqnpt-tXVVUI/edit?usp=sharing

# %%
sheet_id = '1FYVtRCeZIB-tp1mikSyH1E0vsQb5zMYCqnpt-tXVVUI'

# %%
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
dados_cp2_sheets = pd.read_csv(url)

# %%
dados_cp2_sheets.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %% [markdown]
# Ilustrativo

# %%
'''sheet_id = '1lzq0k-41-MbbS63C3Q9i1wPvLkSJt9zhr4Jolt1vEog'
sheet_name = 'emissoes_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}''''

# %%
'''percapita_sheets = pd.read_csv(url_percapita)'''

# %% [markdown]
# # Exercícios

# %%
import requests
import chardet

url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv'
r = requests.get(url)
c = r.content
encoding = chardet.detect(c)['encoding']
print(encoding)

# %%
pd.read_csv(url, encoding='ISO-8859-1', sep=';', skiprows=3)

# %%
dados = pd.read_csv(url, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter = 9, engine='python')
dados

# %%
# https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit?usp=sharing
sheet_id = '1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'
dados = pd.read_csv(url)

# %%
dados.to_csv('emissao_co2.csv', index=False)

# %%
pd.read_csv('/content/emissao_co2.csv')
# Out:
#      Country Name country_code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name           1990           1991  \
# 0    CO2 emissions (metric tons per capita)            NaN            NaN
# 1    CO2 emissions (metric tons per capita)    191.745.115    167.681.579
# ...

# %% [markdown]
# # JSON

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/pacientes.json'
url_2 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/pacientes_2.json'

# %%
dados_pacientes = pd.read_json(url)

# %%
dados_pacientes
# Out:
#      ID_paciente Doenca_cardiaca    IMC Fumante Consumo_alcool  AVC  \
# 0              0             Nao  16.60     Sim            Nao  Nao
# 1              1             Nao  20.34     Nao            Nao  Sim
# 2              2             Nao  26.58     Sim            Nao  Nao
# 3              3             Nao  24.21     Nao            Nao  Nao
# 4              4             Nao  23.71     Nao            Nao  Nao
# ..           ...             ...    ...     ...            ...  ...
# 995          995             Nao  28.29     Sim            Nao  Nao
# 996          996             Nao  25.69     Sim            Nao  Nao
# 997          997             Sim  26.99     Nao            Nao  Nao
# 998          998             Nao  44.29     Nao            Nao  Nao
# 999          999             Nao  25.83     Nao            Nao  Nao
#
#      Saude_fisica  Saude_mental Dificuldade_caminhar Sexo_biologico  \
# 0               3            30                  Nao       Feminino
# ...

# %% [markdown]
# Informações aninhadas

# %%
dados_pacientes_2 = pd.read_json(url_2)

# %%
dados_pacientes_2
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
df_normalizado = pd.json_normalize(dados_pacientes_2['Pacientes'])

# %%
df_normalizado
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
df_normalizado.to_json('historico_pacientes_normalizados.json')

# %%
pd.read_json('/content/historico_pacientes_normalizados.json')
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0   1        55-59       Feminino  Branca  16.60     Sim            Nao
# 1   2      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2   3        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %% [markdown]
# Transformando JSON em csv

# %%
df_normalizado.to_csv('historico_pacientes_normalizados.csv', index = False, sep = ';')

# %%
pd.read_csv('/content/historico_pacientes_normalizados.csv', sep = ';')
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0   1        55-59       Feminino  Branca  16.60     Sim            Nao
# 1   2      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2   3        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                      Problemas_saude
# 0   Muito boa           5  ['Diabetes', 'Asma', 'Cancer_pele']
# 1   Muito boa           7                              ['AVC']
# 2   Muito boa           8                 ['diabetes', 'Asma']

# %% [markdown]
# # Exercícios JSON

# %%
'''#Importando a biblioteca Pandas
import pandas as pd

#Importando o módulo JSON
import json

#Lendo o arquivo json usando o módulo Python JSON
with open('pacientes_2.json','r') as f:
    dados = json.loads(f.read())

#Normalizando os dados com os parâmetros record_path e meta
pd.json_normalize(dados, record_path='Pacientes', meta=['Pesquisa', 'Ano'])'''
# Out:
# "#Importando a biblioteca Pandas\nimport pandas as pd\n\n#Importando o módulo JSON\nimport json\n\n#Lendo o arquivo json usando o módulo Python JSON\nwith open('pacientes_2.json','r') as f:\n    dados = json.loads(f.read())\n\n#Normalizando os dados com os parâmetros record_path e meta\npd.json_normalize(dados, record_path='Pacientes', meta=['Pesquisa', 'Ano'])"

# %%
json_lista = [
    { 'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_biologico': 'feminino'},
    { 'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_biologico': 'feminino'}
]
pd.json_normalize(json_lista)
# Out:
#    ID Faixa_etaria Sexo_biologico
# 0  01        55-59       feminino
# 1  02      80 ou +       feminino

# %%
json_obj = {
    'ID': '01',
    'Faixa_etaria': '55-59',
    'Sexo_biologico': 'Feminino',
    'Saude': {'Dificuldade_caminhar': 'Nao',
              'Atividade_fisica': 'Sim',
              'IMC': 16.6,
              'Doenca_cardiaca': 'Nao',
          }
      }
pd.json_normalize(json_obj)
# Out:
#    ID Faixa_etaria Sexo_biologico Saude.Dificuldade_caminhar  \
# 0  01        55-59       Feminino                        Nao
#
#   Saude.Atividade_fisica  Saude.IMC Saude.Doenca_cardiaca
# 0                    Sim       16.6                   Nao

# %%
pd.json_normalize(json_obj['Saude'])
# Out:
#   Dificuldade_caminhar Atividade_fisica   IMC Doenca_cardiaca
# 0                  Nao              Sim  16.6             Nao

# %%
dados_dict = {
  "Pesquisa": "Principais Indicadores de Doenca Cardiaca",
  "Ano": 2020,
  "Pacientes": [
    {
      "ID": "01",
      "Faixa_etaria": "55-59",
      "Sexo_biologico": "Feminino",
      "Raça": "Branca",
      "IMC": 16.6,
      "Fumante": "Sim",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 3,
      "Saude_mental": 30,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 5,
      "Problemas_saude": [
        "Diabetes",
        "Asma",
        "Cancer_pele"
      ]
    },
    {
      "ID": "02",
      "Faixa_etaria": "80 ou +",
      "Sexo_biologico": "Feminino",
      "Raça": "Branca",
      "IMC": 20.34,
      "Fumante": "Nao",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 0,
      "Saude_mental": 0,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 7,
      "Problemas_saude": [
        "AVC"
      ]
    },
    {
      "ID": "03",
      "Faixa_etaria": "65-69",
      "Sexo_biologico": "Masculino",
      "Raça": "Branca",
      "IMC": 26.58,
      "Fumante": "Sim",
      "Consumo_alcool": "Nao",
      "Saude_fisica": 20,
      "Saude_mental": 30,
      "Dificuldade_caminhar": "Nao",
      "Atividade_fisica": "Sim",
      "Saude_geral": "Muito boa",
      "Horas_sono": 8,
      "Problemas_saude": [
        "diabetes",
        "Asma"
      ]
    }
  ]
}

# %%
pd.json_normalize(dados_dict['Pacientes'])
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
pd.json_normalize(dados_dict, record_path=['Pacientes'])
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
pd.json_normalize(dados_dict,
                  record_path=['Pacientes'],
                  meta=['Pesquisa', 'Ano'])
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude  \
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]
#
#                                     Pesquisa   Ano
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# ...

# %%
pd.DataFrame(dados_dict)
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
pd.json_normalize(dados_dict,
                  record_path=['Pacientes'],
                  meta=['Pesquisa', 'Ano'])
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude  \
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]
#
#                                     Pesquisa   Ano
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# ...

# %%
import requests
import json
import pandas as pd

# %%
url = 'https://fruityvice.com/api/fruit/all'

# %%
dados_frutas = requests.get(url)
dados_fruta_json = json.loads(dados_frutas.text)
df_frutas = pd.DataFrame(dados_fruta_json)
df_frutas

# %%
desafio = pd.read_json(url)

# %%
response = requests.get(url).text

# %%
dados_fruta = json.loads(response)

# %%
pd.DataFrame(dados_fruta)

# %% [markdown]
# # HTML XML

# %%
import pandas as pd

# %%
dados_html = pd.read_html("/content/AFI's_100_Years[1].100_Movies")

# %%
dados_html

# %%
type(dados_html)
# Out:
# list

# %%
len(dados_html)
# Out:
# 2

# %%
dados_html = dados_html[1]

# %%
dados_html
# Out:
#                       Film  Release year              Director  \
# 0             Citizen Kane          1941          Orson Welles
# 1               Casablanca          1942        Michael Curtiz
# 2            The Godfather          1972  Francis Ford Coppola
# 3       Gone with the Wind          1939        Victor Fleming
# 4       Lawrence of Arabia          1962            David Lean
# ..                     ...           ...                   ...
# 118        Sophie's Choice          1982        Alan J. Pakula
# 119  The Last Picture Show          1971     Peter Bogdanovich
# 120     Do the Right Thing          1989             Spike Lee
# 121           Blade Runner          1982          Ridley Scott
# 122              Toy Story          1995         John Lasseter
#
#                               Production companies 1998 Rank 2007 Rank
# 0                               RKO Radio Pictures         1         1
# ...

# %%
dados_html.to_html('dados_filmes.html')

# %%
dados_html.to_excel('dados_filmes.xlsx', index=False)

# %%
dados_xml = pd.read_xml('/content/imdb_top_1000.xml')

# %%
dados_xml.head(3)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
# ...

# %%
dados_xml.to_xml('filmes_imdb.xml')

# %%
url = 'https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o'
df_populacao_mundial = pd.read_html(url)[0]

# %%
df_populacao_mundial
# Out:
#      Unnamed: 0 Posição    País (ou território dependente) Estimativa da ONU  \
# 0           NaN       1                              Índia     1 429 921 746
# 1           NaN       2                              China     1 426 391 281
# 2           NaN       3                     Estados Unidos       339 987 103
# 3           NaN       4                          Indonésia       277 184 719
# 4           NaN       5                          Paquistão       240 215 932
# ..          ...     ...                                ...               ...
# 245         NaN       –     Ilha de Ascensão (Reino Unido)               806
# 246         NaN     195                           Vaticano               801
# 247         NaN       –  Ilhas Cocos (Keeling) (Austrália)               573
# 248         NaN       –     Tristão da Cunha (Reino Unido)               241
# 249         NaN       –       Ilhas Pitcairn (Reino Unido)                63
#
# ...

# %% [markdown]
# # Banco de Dados

# %%
import pandas as pd
import sqlalchemy

# %%
sqlalchemy.__version__
# Out:
# '1.4.51'

# %%
# !pip install --upgrade 'sqlalchemy<2.0'

# %%
sqlalchemy.__version__
# Out:
# '1.4.51'

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect

# %%
engine = create_engine('sqlite:///:memory:')

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

# %%
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# ...

# %%
dados.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %%
inspector =  inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['clientes']

# %%
query =  'SELECT * FROM clientes WHERE Categoria_de_renda = "Empregado"'

# %%
empregados = pd.read_sql(query, engine)

# %%
empregados
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
empregados.to_sql('empregados', con=engine, index=False)
# Out:
# 226059

# %%
pd.read_sql_table('empregados', engine).head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008815     46   Ensino superior         Casado                2
# 4     5112956     46   Ensino superior         Casado                2
#
#   Categoria_de_renda       Ocupacao  Anos_empregado  Rendimento_anual  \
# 0          Empregado          Outro              12          427500.0
# 1          Empregado          Outro              12          427500.0
# 2          Empregado      Segurança               3          112500.0
# 3          Empregado  Contabilidade               2          270000.0
# 4          Empregado  Contabilidade               2          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# ...

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
pd.read_sql_table('empregados', engine, columns= ['ID_Cliente', 'Grau_escolaridade', 'Rendimento_anual'])
# Out:
#         ID_Cliente Grau_escolaridade  Rendimento_anual
# 0          5008804   Ensino superior          427500.0
# 1          5008805   Ensino superior          427500.0
# 2          5008806      Ensino médio          112500.0
# 3          5008815   Ensino superior          270000.0
# 4          5112956   Ensino superior          270000.0
# ...            ...               ...               ...
# 226054     6837905      Ensino médio          355050.0
# 226055     6837906      Ensino médio          355050.0
# 226056     6839936      Ensino médio          135000.0
# 226057     6840222      Ensino médio          103500.0
# 226058     6842885      Ensino médio          121500.0
#
# [226059 rows x 3 columns]

# %%
query = 'DELETE FROM clientes WHERE ID_Cliente=5008804'
with engine.connect() as conn:
  conn.execute(query)

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008805     32   Ensino superior  União-estável                2
# 1          5008806     58      Ensino médio         Casado                2
# 2          5008808     52      Ensino médio       Solteiro                1
# 3          5008809     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
query = 'UPDATE clientes SET Grau_escolaridade="Ensino superior" WHERE ID_Cliente=5008808'

# %%
with engine.connect() as conn:
  conn.execute(query)

# %%
pd.read_sql_table('clientes', engine).head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008805     32   Ensino superior  União-estável                2
# 1     5008806     58      Ensino médio         Casado                2
# 2     5008808     52   Ensino superior       Solteiro                1
# 3     5008809     52      Ensino médio       Solteiro                1
# 4     5008810     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado  Segurança               3          112500.0
# 2  Associado comercial     Vendas               8          270000.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1  Casa/apartamento próprio
# ...

# %% [markdown]
# # Exercicio Final

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine, MetaData, inspection, table

# %%
base = create_engine('sqlite:///:memory:')

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

# %%
dados = pd.read_csv(url)

# %%
dados.to_sql('tratando_dados', base, index=False)
# Out:
# 438463

# %%
pd.read_sql_table('tratando_dados', base).head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# ...

# %%
verificar1 = 'SELECT * FROM tratando_dados WHERE ID_Cliente = 6840104'
pd.read_sql(verificar1, base)
# Out:
#    ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0     6840104     62      Ensino médio   Divorciado                1
#
#   Categoria_de_renda Ocupacao  Anos_empregado  Rendimento_anual  Tem_carro  \
# 0        Pensionista    Outro               0          135000.0          0
#
#                     Moradia
# 0  Casa/apartamento próprio

# %%
query1 = 'UPDATE tratando_dados SET Rendimento_anual = 300000 WHERE ID_Cliente = 6840104'
with base.connect() as conn:
  conn.execute(query1)

# %%
pd.read_sql(verificar1, base)
# Out:
#    ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0     6840104     62      Ensino médio   Divorciado                1
#
#   Categoria_de_renda Ocupacao  Anos_empregado  Rendimento_anual  Tem_carro  \
# 0        Pensionista    Outro               0          300000.0          0
#
#                     Moradia
# 0  Casa/apartamento próprio

# %%
verificar2 = 'SELECT * FROM tratando_dados WHERE ID_Cliente = 5008809'
pd.read_sql(verificar2, base)
# Out:
#    ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0     5008809     52      Ensino médio     Solteiro                1
#
#     Categoria_de_renda Ocupacao  Anos_empregado  Rendimento_anual  Tem_carro  \
# 0  Associado comercial   Vendas               8          270000.0          0
#
#                     Moradia
# 0  Casa/apartamento próprio

# %%
query2 = 'DELETE FROM tratando_dados WHERE ID_Cliente = 5008809'
with base.connect() as conn:
  conn.execute(query2)

# %%
pd.read_sql(verificar2, base)
# Out:
# Empty DataFrame
# Columns: [ID_Cliente, Idade, Grau_escolaridade, Estado_civil, Tamanho_familia, Categoria_de_renda, Ocupacao, Anos_empregado, Rendimento_anual, Tem_carro, Moradia]
# Index: []

# %%
verificar3 = 'SELECT * FROM tratando_dados WHERE ID_Cliente = 6850985'
pd.read_sql(verificar3, base)
# Out:
# Empty DataFrame
# Columns: [ID_Cliente, Idade, Grau_escolaridade, Estado_civil, Tamanho_familia, Categoria_de_renda, Ocupacao, Anos_empregado, Rendimento_anual, Tem_carro, Moradia]
# Index: []

# %%
query3 = 'INSERT INTO tratando_dados (ID_Cliente,	Idade, Grau_escolaridade,	Estado_civil, ' \
'Tamanho_familia,	Categoria_de_renda,	Ocupacao,	Anos_empregado,	Rendimento_anual, Tem_carro, Moradia) ' \
'VALUES (6850985, 33, "Doutorado", "Solteiro", 1, "Empregado", "TI", 2, 290000, 0, "Casa/apartamento próprio")'

with base.connect() as conn:
  conn.execute(query3)

# %%
pd.read_sql(verificar3, base)
# Out:
#    ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0     6850985     33         Doutorado     Solteiro                1
#
#   Categoria_de_renda Ocupacao  Anos_empregado  Rendimento_anual  Tem_carro  \
# 0          Empregado       TI               2          290000.0          0
#
#                     Moradia
# 0  Casa/apartamento próprio
